# %%
import PySimpleGUI as sg

T = sg.TreeData()
T.Insert('', 'node1', '家康', values=['folder', 1], icon='')
T.Insert('node1', 'node11', '信康', values=['folder', 2], icon='')
T.Insert('node1', 'node12', '秀康', values=['folder', 2], icon='')
T.Insert('node1', 'node13', '秀忠', values=['folder', 2], icon='')
T.Insert('node1', 'node14', '忠輝', values=['folder', 2], icon='')
T.Insert('node1', 'node15', '義直', values=['folder', 2], icon='')
T.Insert('node1', 'node16', '頼信', values=['folder', 2], icon='')
T.Insert('node1', 'node17', '頼房', values=['folder', 2], icon='')

T.Insert('node13', 'node130', '家光', values=['folder', 3], icon='')
T.Insert('node13', 'node131', '忠長', values=['folder', 3], icon='')
T.Insert('node13', 'node132', '和子', values=['folder', 3], icon='')
T.Insert('node13', 'node133', '正之', values=['folder', 3], icon='')
T.Insert('node16', 'node160', '光貞', values=['folder', 3], icon='')
T.Insert('node17', 'node170', '略', values=['folder', 3], icon='')

T.Insert('node130', 'node1300', '家綱', values=['folder', 4], icon='')
T.Insert('node130', 'node1301', '綱重', values=['folder', 4], icon='')
T.Insert('node130', 'node1302', '綱吉', values=['folder', 4], icon='')
T.Insert('node160', 'node1601', '吉宗', values=['folder', 4], icon='')
T.Insert('node170', 'node1700', '略', values=['folder', 4], icon='')

T.Insert('node1301', 'node13010', '家宣', values=['folder', 5], icon='')
T.Insert('node1601', 'node16010', '家重', values=['folder', 5], icon='')
T.Insert('node1601', 'node16011', '宗武', values=['folder', 5], icon='')
T.Insert('node1601', 'node16012', '宗尹', values=['folder', 5], icon='')
T.Insert('node1700', 'node17000', '略', values=['folder', 5], icon='')

T.Insert('node13010', 'node130100', '家継', values=['folder', 6], icon='')
T.Insert('node16010', 'node160100', '家治', values=['folder', 6], icon='')
T.Insert('node16010', 'node160101', '重好', values=['folder', 6], icon='')
T.Insert('node16011', 'node160110', '定信', values=['folder', 6], icon='')
T.Insert('node16012', 'node160120', '治済', values=['folder', 6], icon='')
T.Insert('node17000', 'node170000', '斉昭', values=['folder', 6], icon='')

T.Insert('node160120', 'node1601200', '家斉', values=['folder', 7], icon='')
T.Insert('node160120', 'node1601201', '斉敦', values=['folder', 7], icon='')
T.Insert('node160120', 'node1601202', '斉匡', values=['folder', 7], icon='')
T.Insert('node170000', 'node1700000', '慶喜', values=['folder', 7], icon='')

T.Insert('node1601200', 'node16012000', '家慶', values=['folder', 8], icon='')
T.Insert('node1601202', 'node16012001', '斉順', values=['folder', 8], icon='')
T.Insert('node1601200', 'node16012020', '慶頼', values=['folder', 8], icon='')

T.Insert('node16012000', 'node160120000', '家定', values=['folder', 9], icon='')
T.Insert('node16012020', 'node160120010', '家茂', values=['folder', 9], icon='')
T.Insert('node16012020', 'node160120200', '家達', values=['folder', 9], icon='')


H = ['種別', '深さ']
L = [[sg.Tree(T, headings=H, num_rows = 10
              , auto_size_columns=False, col0_width=30, def_col_width=10)]]

window = sg.Window('TokugawaTree', L)

# イベントループ
while True:
    event, values = window.read() # イベントの読み取り
    if event is None: # 終了条件
        break

# 終了処理
window.close()
